# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 1054
x
# Out:
# 1054

# %%
# tampilkan tipe data dari x
type (x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 4501
y
# Out:
# 4501

# %%
# tampilkan tipe data dari y
type (y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 5555

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 10.54
x_float
# Out:
# 10.54

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 45.54

# %%
# tampilkan tipe data dari x_float
type (x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable (1054, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=1054>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(4501, dtype=tf.int16)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=4501>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=5555>
