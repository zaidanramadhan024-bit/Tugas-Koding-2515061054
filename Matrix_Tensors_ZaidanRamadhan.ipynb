# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
x = np.array([[25, 15, 61],
              [54, 45, 25]])
x
# Out:
# array([[25, 15, 61],
#        [54, 45, 25]])

# %%
# tampilkan ukuran dari matrix X
x.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x[:,0]
# Out:
# array([25, 54])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x[1,:]
# Out:
# array([54, 45, 25])

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
# buat matrix X berukuran 2x3 menggunakan pytorch
x_pt = torch.tensor([[15, 54, 25],
              [25, 61, 54]])
x_pt
# Out:
# tensor([[15, 54, 25],
#         [25, 61, 54]])

# %%
# tampilkan ukuran dari matrix X
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x_pt[:,0]
# Out:
# tensor([15, 25])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x_pt[1,:]
# Out:
# tensor([25, 61, 54])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
# buat matrix X berukuran 2x3 menggunakan tensorflow
x_tf = tf.Variable([[55, 54, 25],
                    [61, 15, 54]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[55, 54, 25],
#        [61, 15, 54]], dtype=int32)>

# %%
# tampilkan ukuran dari matrix X
tf.shape(x_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([55, 61], dtype=int32)>

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([61, 15, 54], dtype=int32)>
