# %%
import numpy as np

# %%
# array
x = np.array([
    [25],
    [2],
    [-3],
    [-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
# transpose
x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])
